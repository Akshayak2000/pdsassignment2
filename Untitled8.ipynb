# %%
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv('/content/train.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# #Looking for missing values

# %%
missing_values = data.isnull().sum()

# %%
print("Missing values") #kind of statement
# Out:
# Missing values

# %%
print(missing_values) #prints all the missing values
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %% [markdown]
# #Replacing with the Mean,mode,Median or drop them

# %%
data['Mileage'] = data['Mileage'].str.replace(r'\D', '', regex=True)

# %%
data['Mileage'] = pd.to_numeric(data['Mileage'], errors='coerce')

# %%
data['Mileage'].fillna(data['Mileage'].mean(), inplace=True)

# %%
data['Engine'] = data['Engine'].str.replace(r'\D', '', regex=True)

# %%
data['Engine'] = pd.to_numeric(data['Engine'], errors='coerce')

# %%
data['Engine'].fillna(data['Engine'].mean(), inplace=True)

# %%
data['Power'] = data['Power'].str.replace(r'\D', '', regex=True)

# %%
data['Power'] = pd.to_numeric(data['Power'], errors='coerce')

# %%
data['Power'].fillna(data['Power'].mean(), inplace=True)

# %%
data['Seats'].fillna(data['Seats'].mean(), inplace=True)

# %%
data.drop(columns=['New_Price'], inplace=True)

# %%
updated_missing_values = data.isnull().sum()

# %%
print("Updated missing values in individual coloum")
# Out:
# Updated missing values in individual coloum

# %%
print(updated_missing_values)
# Out:
# Unnamed: 0           0
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# Engine,power,seats,milage are considered as crucial factors of used car, Based on these factors ,It allows us to predict car performance,durability,condition and price.
# Removing these columns will make your dataset less dimensional also helps to enhance interpretability of analysis New pricing *High Values Missed*The "New Price" data may not be accurate or up to date, even if you were to impute missing values. This could introduce errors or noise into our analysis

# %% [markdown]
# #b)Removing specific units may not be needed as we already did in the earlier step

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              41000    Diesel       Manual      First   1967.0  1582.0
# 1              46000    Petrol       Manual      First     13.0  1199.0
# 2              87000    Diesel       Manual      First   2077.0  1248.0
# 3              40670    Diesel    Automatic     Second    152.0  1968.0
# 4              86999    Diesel       Manual      First   2308.0  1461.0
#
#     Power  Seats  Price
# 0  1262.0    5.0  12.50
# 1   887.0    5.0   4.50
# 2  8876.0    7.0   6.00
# 3  1408.0    5.0  17.74
# ...

# %% [markdown]
# #C) Change the categorical variables

# %%
data = pd.get_dummies(data, columns=['Fuel_Type', 'Transmission'], drop_first=True)

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First   1967.0  1582.0  1262.0    5.0  12.50
# 1              46000      First     13.0  1199.0   887.0    5.0   4.50
# 2              87000      First   2077.0  1248.0  8876.0    7.0   6.00
# 3              40670     Second    152.0  1968.0  1408.0    5.0  17.74
# 4              86999      First   2308.0  1461.0   631.0    5.0   3.50
#
#    Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual
# 0                   0                 0                    1
# ...

# %% [markdown]
# #d)Create one more feature and add this column to the dataset

# %%
data['Kilometers_Per_Year'] = data['Kilometers_Driven'] / (2024 - data['Year'])
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First   1967.0  1582.0  1262.0    5.0  12.50
# 1              46000      First     13.0  1199.0   887.0    5.0   4.50
# 2              87000      First   2077.0  1248.0  8876.0    7.0   6.00
# 3              40670     Second    152.0  1968.0  1408.0    5.0  17.74
# 4              86999      First   2308.0  1461.0   631.0    5.0   3.50
#
#    Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual  Car_Age  \
# ...

# %%
current_year = datetime.now().year

# %%
data['Car_Age'] = current_year - data['Year']

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price',
#        'Fuel_Type_Electric', 'Fuel_Type_Petrol', 'Transmission_Manual',
#        'Car_Age'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First   1967.0  1582.0  1262.0    5.0  12.50
# 1              46000      First     13.0  1199.0   887.0    5.0   4.50
# 2              87000      First   2077.0  1248.0  8876.0    7.0   6.00
# 3              40670     Second    152.0  1968.0  1408.0    5.0  17.74
# 4              86999      First   2308.0  1461.0   631.0    5.0   3.50
#
#    Fuel_Type_Electric  Fuel_Type_Petrol  Transmission_Manual  Car_Age
# 0                   0                 0                    1        9
# ...

# %%
data.to_csv('cleandataset_train.csv', index = False)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price',
#        'Fuel_Type_Electric', 'Fuel_Type_Petrol', 'Transmission_Manual',
#        'Car_Age'],
#       dtype='object')

# %%
selected_col = data[[ 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price', 'Fuel_Type_Electric', 'Fuel_Type_Petrol', 'Transmission_Manual', 'Kilometers_Per_Year']]
selected_col
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 1                         Honda Jazz V     Chennai  2011              46000
# 2                    Maruti Ertiga VDI     Chennai  2012              87000
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 4               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 5842                  Maruti Swift VDI       Delhi  2014              27365
# 5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5844             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5845                Maruti Wagon R VXI     Kolkata  2013              46000
# 5846             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
filter = data[data['Year'] >= 2016]
filter
# Out:
#       Unnamed: 0                               Name Location  Year  \
# 5              7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016
# 8             10                   Maruti Ciaz Zeta    Kochi  2018
# 14            16              Honda Amaze S i-Dtech    Kochi  2016
# 15            17              Maruti Swift DDiS VDI   Jaipur  2017
# 26            28                Honda WRV i-VTEC VX    Kochi  2018
# ...          ...                                ...      ...   ...
# 5812        5982                      Tata Hexa XTA   Jaipur  2016
# 5816        5987         Tata Tiago 1.2 Revotron XT    Kochi  2017
# 5825        5996         Jaguar XF 2.2 Litre Luxury    Kochi  2016
# 5827        5999              Tata Bolt Revotron XT  Chennai  2016
# 5833        6005           Maruti Vitara Brezza VDi     Pune  2016
#
#       Kilometers_Driven Owner_Type  Mileage  Engine    Power  Seats  Price  \
# 5                 36000      First   1136.0  2755.0   1715.0    8.0  17.50
# ...

# %%
rename = data.rename(columns={'Kilometers_Driven': 'KM_Driven', 'Price': 'Car_Price'})
rename
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       KM_Driven Owner_Type  Mileage  Engine   Power  Seats  Car_Price  \
# ...

# %%
data['Current_Age'] = 2024 - data['Year']
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# ...

# %%
arranging_data = data.sort_values(by='Year', ascending=True)
arranging_data
# Out:
#       Unnamed: 0                                      Name    Location  Year  \
# 5558        5716                             Maruti Zen LX      Jaipur  1998
# 3039        3138                            Maruti Zen LXI      Jaipur  1998
# 3630        3749         Mercedes-Benz E-Class 250 D W 210      Mumbai  1998
# 1791        1845                        Honda City 1.3 EXI        Pune  1999
# 1185        1224                             Maruti Zen VX      Jaipur  1999
# ...          ...                                       ...         ...   ...
# 4956        5102                        Maruti Wagon R VXI       Kochi  2019
# 5712        5875  Mercedes-Benz C-Class Progressive C 220d   Ahmedabad  2019
# 1486        1534               Honda City i VTEC VX Option  Coimbatore  2019
# 4319        4452            Toyota Innova Crysta 2.8 GX AT       Kochi  2019
# 2511        2595           Tata Tiago AMT 1.2 Revotron XZA  Coimbatore  2019
#
# ...

# %%
grouping_data = data.groupby('Location').agg({'Price': 'mean', 'Kilometers_Driven': 'sum'})
grouping_data
# Out:
#                 Price  Kilometers_Driven
# Location
# Ahmedabad    8.567248           11984485
# Bangalore   13.482670           20496207
# Chennai      7.958340           43075555
# Coimbatore  15.160206           29625311
# Delhi        9.881944           30880339
# Hyderabad    9.997423           50162673
# Jaipur       5.916725           28658786
# Kochi       11.309109           28619518
# Kolkata      5.733924           22812326
# Mumbai       9.592546           34035614
# Pune         6.951000           41173243
